# %% [markdown]
# # PCA_for_Spotify_Recs
#
# **Name(s)**: (your name(s) here)
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## Step 1: Introduction

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("Data/spotify.csv")
data.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre playlist_subgenre  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop         dance pop
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# 3         0.718   0.930    7    -3.778     1       0.1020        0.0287
# 4         0.650   0.833    1    -4.672     1       0.0359        0.0803
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.0653    0.518  122.036       194754
# 1          0.004210    0.3570    0.693   99.972       162600
# 2          0.000023    0.1100    0.613  124.008       176616
# 3          0.000009    0.2040    0.277  121.956       169093
# 4          0.000000    0.0833    0.725  123.976       189052

# %%
#data.info()

# %%
data.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
cols_to_drop = ['track_id', 'track_name', 'track_artist', 'track_album_id', 'track_album_name','playlist_name', 'playlist_id', 'mode']
num_data = data.drop(columns=cols_to_drop)
num_data
# Out:
#        track_popularity track_album_release_date playlist_genre  \
# 0                    66               2019-06-14            pop
# 1                    67               2019-12-13            pop
# 2                    70               2019-07-05            pop
# 3                    60               2019-07-19            pop
# 4                    69               2019-03-05            pop
# ...                 ...                      ...            ...
# 32828                42               2014-04-28            edm
# 32829                20               2013-03-08            edm
# 32830                14               2014-04-21            edm
# 32831                15               2014-01-01            edm
# 32832                27               2014-03-03            edm
#
#                playlist_subgenre  danceability  energy  key  loudness  \
# 0                      dance pop         0.748   0.916    6    -2.634
# 1                      dance pop         0.726   0.815   11    -4.969
# 2                      dance pop         0.675   0.931    1    -3.432
# 3                      dance pop         0.718   0.930    7    -3.778
# 4                      dance pop         0.650   0.833    1    -4.672
# ...                          ...           ...     ...  ...       ...
# 32828  progressive electro house         0.428   0.922    2    -1.814
# 32829  progressive electro house         0.522   0.786    0    -4.462
# 32830  progressive electro house         0.529   0.821    6    -4.899
# 32831  progressive electro house         0.626   0.888    2    -3.361
# 32832  progressive electro house         0.603   0.884    5    -4.571
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0583      0.102000          0.000000    0.0653   0.5180
# 1           0.0373      0.072400          0.004210    0.3570   0.6930
# 2           0.0742      0.079400          0.000023    0.1100   0.6130
# 3           0.1020      0.028700          0.000009    0.2040   0.2770
# 4           0.0359      0.080300          0.000000    0.0833   0.7250
# ...            ...           ...               ...       ...      ...
# 32828       0.0936      0.076600          0.000000    0.0668   0.2100
# 32829       0.0420      0.001710          0.004270    0.3750   0.4000
# 32830       0.0481      0.108000          0.000001    0.1500   0.4360
# 32831       0.1090      0.007920          0.127000    0.3430   0.3080
# 32832       0.0385      0.000133          0.341000    0.7420   0.0894
#
#          tempo  duration_ms
# 0      122.036       194754
# 1       99.972       162600
# 2      124.008       176616
# 3      121.956       169093
# 4      123.976       189052
# ...        ...          ...
# 32828  128.170       204375
# 32829  128.041       353120
# 32830  127.989       210112
# 32831  128.008       367432
# 32832  127.984       337500
#
# [32833 rows x 15 columns]

# %%
#[x for x in num_data['track_album_release_date'] if len(x) < 5]

# %%
num_data['track_album_release_date']
# Out:
# 0        2019-06-14
# 1        2019-12-13
# 2        2019-07-05
# 3        2019-07-19
# 4        2019-03-05
#             ...
# 32828    2014-04-28
# 32829    2013-03-08
# 32830    2014-04-21
# 32831    2014-01-01
# 32832    2014-03-03
# Name: track_album_release_date, Length: 32833, dtype: object

# %%
num_data['years'] = [int(x.split('-')[0]) for x in num_data['track_album_release_date']]
num_data = num_data.drop(columns = 'track_album_release_date')
num_data
# Out:
#        track_popularity playlist_genre          playlist_subgenre  \
# 0                    66            pop                  dance pop
# 1                    67            pop                  dance pop
# 2                    70            pop                  dance pop
# 3                    60            pop                  dance pop
# 4                    69            pop                  dance pop
# ...                 ...            ...                        ...
# 32828                42            edm  progressive electro house
# 32829                20            edm  progressive electro house
# 32830                14            edm  progressive electro house
# 32831                15            edm  progressive electro house
# 32832                27            edm  progressive electro house
#
#        danceability  energy  key  loudness  speechiness  acousticness  \
# 0             0.748   0.916    6    -2.634       0.0583      0.102000
# 1             0.726   0.815   11    -4.969       0.0373      0.072400
# 2             0.675   0.931    1    -3.432       0.0742      0.079400
# 3             0.718   0.930    7    -3.778       0.1020      0.028700
# 4             0.650   0.833    1    -4.672       0.0359      0.080300
# ...             ...     ...  ...       ...          ...           ...
# 32828         0.428   0.922    2    -1.814       0.0936      0.076600
# 32829         0.522   0.786    0    -4.462       0.0420      0.001710
# 32830         0.529   0.821    6    -4.899       0.0481      0.108000
# 32831         0.626   0.888    2    -3.361       0.1090      0.007920
# 32832         0.603   0.884    5    -4.571       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms  years
# 0              0.000000    0.0653   0.5180  122.036       194754   2019
# 1              0.004210    0.3570   0.6930   99.972       162600   2019
# 2              0.000023    0.1100   0.6130  124.008       176616   2019
# 3              0.000009    0.2040   0.2770  121.956       169093   2019
# 4              0.000000    0.0833   0.7250  123.976       189052   2019
# ...                 ...       ...      ...      ...          ...    ...
# 32828          0.000000    0.0668   0.2100  128.170       204375   2014
# 32829          0.004270    0.3750   0.4000  128.041       353120   2013
# 32830          0.000001    0.1500   0.4360  127.989       210112   2014
# 32831          0.127000    0.3430   0.3080  128.008       367432   2014
# 32832          0.341000    0.7420   0.0894  127.984       337500   2014
#
# [32833 rows x 15 columns]

# %%
num_data['years']
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 32828    2014
# 32829    2013
# 32830    2014
# 32831    2014
# 32832    2014
# Name: years, Length: 32833, dtype: int64

# %%
#Number of songs from every year

num_data.groupby('years').count()
# Out:
#        track_popularity  playlist_genre  playlist_subgenre  danceability  \
# years
# 1957                  2               2                  2             2
# 1958                  1               1                  1             1
# 1960                  4               4                  4             4
# 1961                  1               1                  1             1
# 1962                  2               2                  2             2
# ...                 ...             ...                ...           ...
# 2016               2127            2127               2127          2127
# 2017               2430            2430               2430          2430
# 2018               3312            3312               3312          3312
# 2019               9081            9081               9081          9081
# 2020                785             785                785           785
#
#        energy   key  loudness  speechiness  acousticness  instrumentalness  \
# years
# 1957        2     2         2            2             2                 2
# 1958        1     1         1            1             1                 1
# 1960        4     4         4            4             4                 4
# 1961        1     1         1            1             1                 1
# 1962        2     2         2            2             2                 2
# ...       ...   ...       ...          ...           ...               ...
# 2016     2127  2127      2127         2127          2127              2127
# 2017     2430  2430      2430         2430          2430              2430
# 2018     3312  3312      3312         3312          3312              3312
# 2019     9081  9081      9081         9081          9081              9081
# 2020      785   785       785          785           785               785
#
#        liveness  valence  tempo  duration_ms
# years
# 1957          2        2      2            2
# 1958          1        1      1            1
# 1960          4        4      4            4
# 1961          1        1      1            1
# 1962          2        2      2            2
# ...         ...      ...    ...          ...
# 2016       2127     2127   2127         2127
# 2017       2430     2430   2430         2430
# 2018       3312     3312   3312         3312
# 2019       9081     9081   9081         9081
# 2020        785      785    785          785
#
# [63 rows x 14 columns]

# %%
num_data.pivot_table(
    index="playlist_genre",
    columns='years',
    values='track_popularity',
    aggfunc='count'
)
# Out:
# years           1957  1958  1960  1961  1962  1963  1964  1965  1966  1967  \
# playlist_genre
# edm              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# latin            NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0   NaN   NaN
# pop              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# r&b              1.0   NaN   4.0   1.0   1.0   1.0   1.0   3.0   3.0   5.0
# rap              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   1.0
# rock             1.0   1.0   NaN   NaN   1.0   4.0   8.0   8.0  16.0  35.0
#
# years           1968  1969  1970  1971  1972  1973  1974  1975   1976  1977  \
# playlist_genre
# edm              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   1.0
# latin            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    1.0   NaN
# pop              NaN   1.0   1.0   NaN   NaN   1.0   1.0   1.0    2.0   1.0
# r&b              2.0   4.0   7.0   4.0   5.0   5.0  10.0   8.0    9.0   3.0
# rap              2.0   1.0   2.0   1.0   1.0   1.0   2.0   NaN    1.0   NaN
# rock            19.0  50.0  72.0  66.0  68.0  97.0  67.0  99.0  120.0  95.0
#
# years            1978  1979  1980  1981  1982  1983   1984   1985  1986  \
# playlist_genre
# edm               1.0   2.0   1.0   1.0   2.0   1.0    NaN    NaN   NaN
# latin             NaN   3.0   NaN   1.0   4.0   2.0    2.0    6.0   5.0
# pop               7.0   4.0   6.0  14.0   8.0  13.0   19.0    9.0  11.0
# r&b               5.0   5.0   5.0   3.0   5.0   7.0   10.0   15.0  28.0
# rap               1.0   NaN   NaN   2.0   2.0   1.0    1.0    3.0   2.0
# rock            116.0  70.0  85.0  66.0  73.0  94.0  108.0  111.0  75.0
#
# years            1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# playlist_genre
# edm               NaN   NaN   NaN   1.0   1.0   NaN   1.0   1.0   1.0   1.0
# latin             9.0  16.0  11.0  17.0  12.0   3.0  13.0  11.0  18.0  13.0
# pop              21.0   9.0  10.0  16.0   7.0   6.0   7.0  15.0  13.0  17.0
# r&b              31.0  62.0  47.0  77.0  84.0  97.0  80.0  72.0  64.0  89.0
# rap               8.0  35.0   5.0  14.0  25.0  41.0  72.0  80.0  75.0  95.0
# rock            114.0  71.0  56.0  46.0  80.0  39.0  51.0  58.0  48.0  35.0
#
# years           1997   1998  1999   2000  2001   2002   2003  2004   2005  \
# playlist_genre
# edm              NaN    1.0   3.0    4.0   3.0    4.0    5.0   3.0    8.0
# latin           23.0   21.0  26.0   14.0  26.0   19.0   47.0  76.0   69.0
# pop             12.0   13.0  18.0    9.0  33.0   23.0   28.0  24.0   22.0
# r&b             89.0   65.0  75.0  101.0  97.0  100.0  103.0  93.0  107.0
# rap             49.0  111.0  89.0   54.0  59.0   54.0   98.0  90.0  126.0
# rock            80.0   72.0  67.0   68.0  94.0   59.0   72.0  99.0  176.0
#
# years            2006   2007   2008   2009   2010   2011   2012   2013   2014  \
# playlist_genre
# edm              16.0   29.0   43.0   45.0   37.0   74.0  170.0  313.0  564.0
# latin            92.0  101.0  119.0  118.0  126.0   84.0  133.0  123.0  165.0
# pop              50.0   50.0  112.0   95.0  173.0  144.0  176.0  227.0  316.0
# r&b              85.0   87.0  131.0   69.0   85.0  125.0  127.0  116.0  199.0
# rap             101.0   88.0   75.0   58.0   74.0   80.0  117.0   93.0  175.0
# rock            101.0  115.0  142.0   88.0  120.0   97.0   63.0   84.0  105.0
#
# years            2015   2016   2017   2018    2019   2020
# playlist_genre
# edm             462.0  498.0  486.0  755.0  2321.0  184.0
# latin           277.0  375.0  396.0  567.0  1879.0  131.0
# pop             479.0  531.0  505.0  704.0  1373.0  170.0
# r&b             247.0  351.0  464.0  452.0  1107.0   93.0
# rap             235.0  295.0  463.0  705.0  1824.0  159.0
# rock             79.0   77.0  116.0  129.0   577.0   48.0

# %%
num_data = num_data[num_data['years']>1989]
num_data
# Out:
#        track_popularity playlist_genre          playlist_subgenre  \
# 0                    66            pop                  dance pop
# 1                    67            pop                  dance pop
# 2                    70            pop                  dance pop
# 3                    60            pop                  dance pop
# 4                    69            pop                  dance pop
# ...                 ...            ...                        ...
# 32828                42            edm  progressive electro house
# 32829                20            edm  progressive electro house
# 32830                14            edm  progressive electro house
# 32831                15            edm  progressive electro house
# 32832                27            edm  progressive electro house
#
#        danceability  energy  key  loudness  speechiness  acousticness  \
# 0             0.748   0.916    6    -2.634       0.0583      0.102000
# 1             0.726   0.815   11    -4.969       0.0373      0.072400
# 2             0.675   0.931    1    -3.432       0.0742      0.079400
# 3             0.718   0.930    7    -3.778       0.1020      0.028700
# 4             0.650   0.833    1    -4.672       0.0359      0.080300
# ...             ...     ...  ...       ...          ...           ...
# 32828         0.428   0.922    2    -1.814       0.0936      0.076600
# 32829         0.522   0.786    0    -4.462       0.0420      0.001710
# 32830         0.529   0.821    6    -4.899       0.0481      0.108000
# 32831         0.626   0.888    2    -3.361       0.1090      0.007920
# 32832         0.603   0.884    5    -4.571       0.0385      0.000133
#
#        instrumentalness  liveness  valence    tempo  duration_ms  years
# 0              0.000000    0.0653   0.5180  122.036       194754   2019
# 1              0.004210    0.3570   0.6930   99.972       162600   2019
# 2              0.000023    0.1100   0.6130  124.008       176616   2019
# 3              0.000009    0.2040   0.2770  121.956       169093   2019
# 4              0.000000    0.0833   0.7250  123.976       189052   2019
# ...                 ...       ...      ...      ...          ...    ...
# 32828          0.000000    0.0668   0.2100  128.170       204375   2014
# 32829          0.004270    0.3750   0.4000  128.041       353120   2013
# 32830          0.000001    0.1500   0.4360  127.989       210112   2014
# 32831          0.127000    0.3430   0.3080  128.008       367432   2014
# 32832          0.341000    0.7420   0.0894  127.984       337500   2014
#
# [30386 rows x 15 columns]

# %%
num_data.pivot_table(
    index="playlist_genre",
    columns='years',
    values='track_popularity',
    aggfunc='count'
)
# Out:
# years           1990  1991  1992  1993  1994  1995  1996  1997   1998  1999  \
# playlist_genre
# edm              1.0   1.0   NaN   1.0   1.0   1.0   1.0   NaN    1.0   3.0
# latin           17.0  12.0   3.0  13.0  11.0  18.0  13.0  23.0   21.0  26.0
# pop             16.0   7.0   6.0   7.0  15.0  13.0  17.0  12.0   13.0  18.0
# r&b             77.0  84.0  97.0  80.0  72.0  64.0  89.0  89.0   65.0  75.0
# rap             14.0  25.0  41.0  72.0  80.0  75.0  95.0  49.0  111.0  89.0
# rock            46.0  80.0  39.0  51.0  58.0  48.0  35.0  80.0   72.0  67.0
#
# years            2000  2001   2002   2003  2004   2005   2006   2007   2008  \
# playlist_genre
# edm               4.0   3.0    4.0    5.0   3.0    8.0   16.0   29.0   43.0
# latin            14.0  26.0   19.0   47.0  76.0   69.0   92.0  101.0  119.0
# pop               9.0  33.0   23.0   28.0  24.0   22.0   50.0   50.0  112.0
# r&b             101.0  97.0  100.0  103.0  93.0  107.0   85.0   87.0  131.0
# rap              54.0  59.0   54.0   98.0  90.0  126.0  101.0   88.0   75.0
# rock             68.0  94.0   59.0   72.0  99.0  176.0  101.0  115.0  142.0
#
# years            2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# playlist_genre
# edm              45.0   37.0   74.0  170.0  313.0  564.0  462.0  498.0  486.0
# latin           118.0  126.0   84.0  133.0  123.0  165.0  277.0  375.0  396.0
# pop              95.0  173.0  144.0  176.0  227.0  316.0  479.0  531.0  505.0
# r&b              69.0   85.0  125.0  127.0  116.0  199.0  247.0  351.0  464.0
# rap              58.0   74.0   80.0  117.0   93.0  175.0  235.0  295.0  463.0
# rock             88.0  120.0   97.0   63.0   84.0  105.0   79.0   77.0  116.0
#
# years            2018    2019   2020
# playlist_genre
# edm             755.0  2321.0  184.0
# latin           567.0  1879.0  131.0
# pop             704.0  1373.0  170.0
# r&b             452.0  1107.0   93.0
# rap             705.0  1824.0  159.0
# rock            129.0   577.0   48.0

# %%
num_data.groupby("playlist_genre")['danceability'].mean()
# Out:
# playlist_genre
# edm      0.654910
# latin    0.713518
# pop      0.640174
# r&b      0.669703
# rap      0.717715
# rock     0.509439
# Name: danceability, dtype: float64

# %%
num_data.groupby("playlist_genre")['energy'].mean()
# Out:
# playlist_genre
# edm      0.802778
# latin    0.708776
# pop      0.700655
# r&b      0.588926
# rap      0.650945
# rock     0.764647
# Name: energy, dtype: float64

# %%
# 12 major keys from 0 to 11
num_data['key'].max()
# Out:
# np.int64(11)

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
# TODO

# %% [markdown]
# ## Step 3: Assessment of Missingness

# %%
# TODO

# %% [markdown]
# ## Step 4: Hypothesis Testing

# %%
# TODO

# %% [markdown]
# ## Step 5: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 6: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 7: Final Model

# %%
# TODO

# %% [markdown]
# ## Step 8: Fairness Analysis

# %%
# TODO
